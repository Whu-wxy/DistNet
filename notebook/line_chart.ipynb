# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator, FormatStrFormatter


font1 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 9,  
} 

font2 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 14,  
}  

figsize = 8, 8
plt.subplots(figsize=figsize, dpi=120)                                # 设定整张图片大小

x = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
# x = []

IC15_F = [1, 1, 1, 1, 1, 1]
IC15_P = [1, 1, 1, 1, 1, 1]
IC15_R = [1, 1, 1, 1, 1, 1]
IC15_FPS = [1, 1, 1, 1, 1, 1]

CTW_F = [2, 2, 2, 2, 2, 2]
CTW_P = [2, 2, 2, 2, 2, 2]
CTW_R = [2, 2, 2, 2, 2, 2]
CTW_FPS = [2, 2, 2, 2, 2, 2]

Total_F = [3, 3 ,3 ,3 ,3, 3]
Total_P = [3, 3 ,3 ,3 ,3, 3]
Total_R = [3, 3 ,3 ,3 ,3, 3]
Total_FPS = [3, 3 ,3 ,3 ,3, 3]

####### 表一
ax1 = plt.subplot(2, 2, 1)
plt.ylim(0, 10) 
plt.title('(a)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('F-score')
#ax1.yaxis.set_major_locator(MultipleLocator(15))             # 设定y轴刻度间距
#第一条线
plt.plot(x, IC15_F, color='black', label='$IC15$', linewidth=0.8, marker='.')  # 绘制，指定颜色、标签、线宽，标签采用latex格式                                          # 设定y轴范围
hl=plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置
#set(hl,'Box','off');
#第二条线
plt.plot(x, CTW_F, color='red', label='$CTW$', linewidth=0.8, linestyle='-.', marker='x')
plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_F, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置

plt.xticks([])                                               # 去掉x坐标轴刻度
#plt.xlim(0, 580)                                             # 设定x轴范围

####### 表二
ax2 = plt.subplot(2, 2, 2)
plt.ylim(0, 10)
plt.title('(b)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Precision')
#ax2.yaxis.set_major_locator(MultipleLocator(15))
#第一条线
plt.plot(x, IC15_P, color='black', label='$IC15$', linewidth=0.8, marker='.')  # 绘制，指定颜色、标签、线宽，标签采用latex格式                                          # 设定y轴范围
hl=plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置
#set(hl,'Box','off');
#第二条线
plt.plot(x, CTW_P, color='red', label='$CTW$', linewidth=0.8, linestyle='-.', marker='x')
plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_P, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置

plt.xticks([])                                               # 去掉x坐标轴刻度
#plt.xlim(0, 580)                                             # 设定x轴范围

####### 表三
ax3 = plt.subplot(2, 2, 3)
plt.ylim(0, 10)
plt.title('(c)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Recall')
# ax3.yaxis.set_major_locator(MultipleLocator(15))
#第一条线
plt.plot(x, IC15_R, color='black', label='$IC15$', linewidth=0.8, marker='.')  # 绘制，指定颜色、标签、线宽，标签采用latex格式                                          # 设定y轴范围
hl=plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置
#set(hl,'Box','off');
#第二条线
plt.plot(x, CTW_R, color='red', label='$CTW$', linewidth=0.8, linestyle='-.', marker='x')
plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置

#三
plt.plot(x, Total_R, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置

plt.xticks([])                                               # 去掉x坐标轴刻度
#plt.xlim(0, 580)                                             # 设定x轴范围

####### 表四
ax4 = plt.subplot(2, 2, 4)
plt.ylim(0, 10)
plt.title('(d)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('FPS')
# ax4.yaxis.set_major_locator(MultipleLocator(15))
#第一条线
plt.plot(x, IC15_FPS, color='black', label='$IC15$', linewidth=0.8, marker='.')  # 绘制，指定颜色、标签、线宽，标签采用latex格式                                          # 设定y轴范围
hl=plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置
#set(hl,'Box','off');
#第二条线
plt.plot(x, CTW_FPS, color='red', label='$CTW$', linewidth=0.8, linestyle='-.', marker='x')
plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_FPS, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', prop=font1, frameon=False)                                # 绘制图例，指定图例位置

plt.xticks([])                                               # 去掉x坐标轴刻度
#plt.xlim(0, 580)                                             # 设定x轴范围






plt.show()

# %%
plt.savefig("../../line_chart.png", dpi=600))
