# %%
# VGG16
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

plt.rc('font',family='Times New Roman') 

font1 = {  
'weight' : 'normal',  
'size'   : 9,  
} 

font2 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 14,  
}  

figsize = 8, 8
plt.subplots(figsize=figsize, dpi=120)                                # 设定整张图片大小

x = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8]

# vgg16
CTW_F =   [78.8, 80.4, 80.4, 79.9, 76.4, 72.8]
CTW_P =   [85.4, 85.8, 84.8, 82.7, 76.9, 71.8]
CTW_R =   [73.2, 75.6, 76.5, 77.2, 75.9, 73.8]
CTW_NUM = [2629, 2704, 2768, 2864, 3028, 3156]

Total_F =   [79.5, 80.2, 81.4, 81.6, 80.7, 79.1]
Total_P =   [85.1, 84.8, 85, 84.2, 81.8, 79.0]
Total_R =   [74.5, 76.0, 78.2, 79.1, 79.6, 79.2]
Total_NUM = [2137, 2191, 2249, 2304, 2398, 2481]

####### 表一
ax1 = plt.subplot(2, 2, 1)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90) 
plt.title('(a)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('F-score')
#第二条线
plt.plot(x, CTW_F, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)   #, prop=font1                               # 绘制图例，指定图例位置
#三
plt.plot(x, Total_F, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_F):
    c = b
#     if a>0.6:
#         c -= 1.5
    plt.text(a, c-1.5, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_F):
    c = b
#     if a==0.6:
#         c -= 1.5
    plt.text(a, c+0.4, b, ha='center', va='bottom')  #, fontsize=10
    
    
####### 表二
ax2 = plt.subplot(2, 2, 2)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90)
plt.title('(b)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Precision')
#第二条线
plt.plot(x, CTW_P, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_P, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_P):
    c = b
    if a>0.4:
        c -= 1.5
    plt.text(a, c+0.2, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_P):
    c = b
    if a<0.5:
        c -= 1.6
    plt.text(a, c+0.4, b, ha='center', va='bottom')  #, fontsize=10

####### 表三
ax3 = plt.subplot(2, 2, 3)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90)
plt.title('(c)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Recall')
#第二条线
plt.plot(x, CTW_R, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

#三
plt.plot(x, Total_R, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_R):
    c = b
#     if a>0.6:
    c -= 1.5
    plt.text(a, c+0.2, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_R):
    c = b
    plt.text(a, c+0.2, b, ha='center', va='bottom')  #, fontsize=10
    
# ####### 表四
ax4 = plt.subplot(2, 2, 4)
plt.xlim(0.2, 0.9)
plt.ylim(2000, 3400)
plt.title('(d)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('number of the detections')

#第二条线
plt.plot(x, CTW_NUM, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_NUM, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_NUM):
    c = b
    if a==0.8:
        c -= 120
    plt.text(a, c+20, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_NUM):
    plt.text(a, b+20, b, ha='center', va='bottom')  #, fontsize=10
    
    

plt.tight_layout()

plt.savefig("../../line_chart.png", dpi=600)
plt.show()

# %%
# DLA34
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

plt.rc('font',family='Times New Roman') 

font1 = {  
'weight' : 'normal',  
'size'   : 9,  
} 

font2 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 14,  
}  

figsize = 8, 8
plt.subplots(figsize=figsize, dpi=120)                                # 设定整张图片大小

x = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8]

# dla
CTW_F =   [78.8, 80.3, 81.3, 81.5, 80.0, 78.0]
CTW_P =   [85.7, 85.8, 85.8, 85.3, 82.4, 79.2]
CTW_R =   [73.0, 75.5, 77.1, 78.1, 77.7, 76.8]
CTW_NUM = [2613, 2699, 2756, 2809, 2893, 2974]

Total_F =   [81.2, 81.8, 82.5, 82.5, 81.6, 80.0]
Total_P =   [86.9, 86.5, 86.4, 85.4, 83.8, 81.2]
Total_R =   [76.2, 77.6, 79.0, 79.7, 79.5, 78.7]
Total_NUM = [2118, 2170, 2219, 2269, 2313, 2369]

####### 表一
ax1 = plt.subplot(2, 2, 1)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90) 
plt.title('(a)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('F-score')
#第二条线
plt.plot(x, CTW_F, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)   #, prop=font1                               # 绘制图例，指定图例位置
#三
plt.plot(x, Total_F, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_F):
    c = b
#     if a>0.6:
#         c -= 1.5
    plt.text(a, c-1.5, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_F):
    c = b
#     if a==0.6:
#         c -= 1.5
    plt.text(a, c+0.4, b, ha='center', va='bottom')  #, fontsize=10
    
    
####### 表二
ax2 = plt.subplot(2, 2, 2)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90)
plt.title('(b)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Precision')
#第二条线
plt.plot(x, CTW_P, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_P, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_P):
    c = b
#     if a>0.4:
#         c -= 1.5
    plt.text(a, c-1.5, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_P):
    c = b
#     if a<0.5:
#         c -= 1.6
    plt.text(a, c+0.4, b, ha='center', va='bottom')  #, fontsize=10

####### 表三
ax3 = plt.subplot(2, 2, 3)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90)
plt.title('(c)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Recall')
#第二条线
plt.plot(x, CTW_R, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

#三
plt.plot(x, Total_R, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_R):
    c = b
#     if a>0.6:
    c -= 1.5
    plt.text(a, c+0.2, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_R):
    c = b
    plt.text(a, c+0.2, b, ha='center', va='bottom')  #, fontsize=10
    
# ####### 表四
ax4 = plt.subplot(2, 2, 4)
plt.xlim(0.2, 0.9)
plt.ylim(2000, 3400)
plt.title('(d)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('number of the detections')

#第二条线
plt.plot(x, CTW_NUM, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_NUM, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_NUM):
    c = b
    plt.text(a, c+20, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_NUM):
    plt.text(a, b+20, b, ha='center', va='bottom')  #, fontsize=10
    
    

plt.tight_layout()

plt.savefig("../../line_chart.png", dpi=600)
plt.show()

# %%
# CTW
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

plt.rc('font',family='Times New Roman') 

font1 = {  
'weight' : 'normal',  
'size'   : 9,  
} 

font2 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 14,  
}  

figsize = 8, 8
plt.subplots(figsize=figsize, dpi=120)                                # 设定整张图片大小

x = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8]

# VGG
CTW_F =   [78.8, 80.4, 80.4, 79.9, 76.4, 72.8]
CTW_P =   [85.4, 85.8, 84.8, 82.7, 76.9, 71.8]
CTW_R =   [73.2, 75.6, 76.5, 77.2, 75.9, 73.8]
CTW_NUM = [2629, 2704, 2768, 2864, 3028, 3156]
# DLA
Total_F =   [78.8, 80.3, 81.3, 81.5, 80.0, 78.0]
Total_P =   [85.7, 85.8, 85.8, 85.3, 82.4, 79.2]
Total_R =   [73.0, 75.5, 77.1, 78.1, 77.7, 76.8]
Total_NUM = [2613, 2699, 2756, 2809, 2893, 2974]

####### 表一
ax1 = plt.subplot(2, 2, 1)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90) 
plt.title('(a)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('F-score')
#第二条线
plt.plot(x, CTW_F, color='red', label='$baseline$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)   #, prop=font1                               # 绘制图例，指定图例位置
#三
plt.plot(x, Total_F, color='blue', label='$ours$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_F):
    c = b
#     if a>0.6:
#         c -= 1.5
    plt.text(a, c-1.5, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_F):
    c = b
#     if a==0.6:
#         c -= 1.5
    plt.text(a, c+0.4, b, ha='center', va='bottom')  #, fontsize=10
    
    
####### 表二
ax2 = plt.subplot(2, 2, 2)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90)
plt.title('(b)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Precision')
#第二条线
plt.plot(x, CTW_P, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_P, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_P):
    c = b
#     if a>0.4:
#         c -= 1.5
    plt.text(a, c-1.5, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_P):
    c = b
#     if a<0.5:
#         c -= 1.6
    plt.text(a, c+0.4, b, ha='center', va='bottom')  #, fontsize=10

####### 表三
ax3 = plt.subplot(2, 2, 3)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90)
plt.title('(c)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Recall')
#第二条线
plt.plot(x, CTW_R, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

#三
plt.plot(x, Total_R, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_R):
    c = b
#     if a>0.6:
    c -= 1.5
    plt.text(a, c+0.2, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_R):
    c = b
    plt.text(a, c+0.2, b, ha='center', va='bottom')  #, fontsize=10
    
# ####### 表四
ax4 = plt.subplot(2, 2, 4)
plt.xlim(0.2, 0.9)
plt.ylim(2000, 3400)
plt.title('(d)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('number of the detections')

#第二条线
plt.plot(x, CTW_NUM, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_NUM, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_NUM):
    c = b
    plt.text(a, c+20, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_NUM):
    plt.text(a, b+20, b, ha='center', va='bottom')  #, fontsize=10
    
    

plt.tight_layout()

plt.savefig("../../line_chart.png", dpi=600)
plt.show()

# %%
# TotalText
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

plt.rc('font',family='Times New Roman') 

font1 = {  
'weight' : 'normal',  
'size'   : 9,  
} 

font2 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 14,  
}  

figsize = 8, 8
plt.subplots(figsize=figsize, dpi=120)                                # 设定整张图片大小

x = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8]

# VGG
CTW_F =   [79.5, 80.2, 81.4, 81.6, 80.7, 79.1]
CTW_P =   [85.1, 84.8, 85, 84.2, 81.8, 79.0]
CTW_R =   [74.5, 76.0, 78.2, 79.1, 79.6, 79.2]
CTW_NUM = [2137, 2191, 2249, 2304, 2398, 2481]
# DLA
Total_F =   [81.2, 81.8, 82.5, 82.5, 81.6, 80.0]
Total_P =   [86.9, 86.5, 86.4, 85.4, 83.8, 81.2]
Total_R =   [76.2, 77.6, 79.0, 79.7, 79.5, 78.7]
Total_NUM = [2118, 2170, 2219, 2269, 2313, 2369]

####### 表一
ax1 = plt.subplot(2, 2, 1)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90) 
plt.title('(a)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('F-score')
#第二条线
plt.plot(x, CTW_F, color='red', label='$baseline$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)   #, prop=font1                               # 绘制图例，指定图例位置
#三
plt.plot(x, Total_F, color='blue', label='$ours$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_F):
    c = b
#     if a>0.6:
#         c -= 1.5
    plt.text(a, c-1.5, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_F):
    c = b
#     if a==0.6:
#         c -= 1.5
    plt.text(a, c+0.4, b, ha='center', va='bottom')  #, fontsize=10
    
    
####### 表二
ax2 = plt.subplot(2, 2, 2)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90)
plt.title('(b)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Precision')
#第二条线
plt.plot(x, CTW_P, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_P, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_P):
    c = b
#     if a>0.4:
#         c -= 1.5
    plt.text(a, c-1.5, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_P):
    c = b
#     if a<0.5:
#         c -= 1.6
    plt.text(a, c+0.4, b, ha='center', va='bottom')  #, fontsize=10

####### 表三
ax3 = plt.subplot(2, 2, 3)
plt.xlim(0.2, 0.9)
plt.ylim(70, 90)
plt.title('(c)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('Recall')
#第二条线
plt.plot(x, CTW_R, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

#三
plt.plot(x, Total_R, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_R):
    c = b
#     if a>0.6:
    c -= 1.5
    plt.text(a, c+0.2, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_R):
    c = b
    plt.text(a, c+0.2, b, ha='center', va='bottom')  #, fontsize=10
    
# ####### 表四
ax4 = plt.subplot(2, 2, 4)
plt.xlim(0.2, 0.9)
plt.ylim(2000, 3400)
plt.title('(d)', fontsize=12)
plt.xlabel('${D}_{max}$')
plt.ylabel('number of the detections')

#第二条线
plt.plot(x, CTW_NUM, color='red', label='$CTW$', linewidth=0.8, marker='.')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置
#三
plt.plot(x, Total_NUM, color='blue', label='$Total$', linewidth=0.8, linestyle='--', marker='+')
plt.legend(loc='upper right', frameon=False)                                # 绘制图例，指定图例位置

for a, b in zip(x, CTW_NUM):
    c = b
    plt.text(a, c+20, b, ha='center', va='bottom')  #, fontsize=10
for a, b in zip(x, Total_NUM):
    plt.text(a, b+20, b, ha='center', va='bottom')  #, fontsize=10
    
plt.tight_layout()

plt.savefig("../../line_chart.png", dpi=600)
plt.show()
